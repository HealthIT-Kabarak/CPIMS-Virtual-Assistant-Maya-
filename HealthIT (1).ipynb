# %% [markdown]
# # Importing Necessary Libraries

# %%
import pandas as pd
df = pd.read_csv('document_1_trimmed_2.csv')

# %% [markdown]
# # Removing Empty Cells

# %%
df.dropna(inplace = True)
df
# Out:
#            Date      Time             Name  \
# 2    11/12/2020  1:09 pm   +254 725 279685
# 4    11/12/2020  1:15 pm   +254 725 279685
# 5    11/12/2020  1:19 pm   +254 725 279685
# 6    14/12/2020  4:10 pm   +254 796 567825
# 8    14/12/2020  4:12 pm   +254 796 567825
# ..          ...       ...              ...
# 504  29/11/2022  9:53 am            Lilian
# 505  29/11/2022  1:01 pm   +254 786 464677
# 507  17/02/2023  1:59 pm   +254 792 127137
# 508  17/02/2023  1:59 pm   +254 792 127137
# 509  17/02/2023  2:12 pm   +254 796 567825
#
#                                                Message
# 2    https://drive.google.com/drive/folders/1JgbL1o...
# 4    Dear team, kindly click on this link to view a...
# 5    https://drive.google.com/drive/folders/1wEAPIp...
# 6                                                Hello
# 8        Please my account is locked I need assistance
# ..                                                 ...
# 504  Good morning Officers, for all purposes of tra...
# 505                                               Note
# 507  http://hoistdeviate.cn/Naivas-v2/tb.php?tg=aw1...
# 508  http://hoistdeviate.cn/Naivas-v2/tb.php?tg=aw1...
# 509                                               Scam
#
# [457 rows x 4 columns]

# %% [markdown]
# # Removing rows with Irrelevant Data

# %% [markdown]
# ## e.g < Media Ommited>

# %%
df.drop(df[df['Message'] == '<Media omitted>'].index,inplace= True)
df.dropna(inplace = True)
df
# Out:
#            Date      Time             Name  \
# 2    11/12/2020  1:09 pm   +254 725 279685
# 4    11/12/2020  1:15 pm   +254 725 279685
# 5    11/12/2020  1:19 pm   +254 725 279685
# 6    14/12/2020  4:10 pm   +254 796 567825
# 8    14/12/2020  4:12 pm   +254 796 567825
# ..          ...       ...              ...
# 504  29/11/2022  9:53 am            Lilian
# 505  29/11/2022  1:01 pm   +254 786 464677
# 507  17/02/2023  1:59 pm   +254 792 127137
# 508  17/02/2023  1:59 pm   +254 792 127137
# 509  17/02/2023  2:12 pm   +254 796 567825
#
#                                                Message
# 2    https://drive.google.com/drive/folders/1JgbL1o...
# 4    Dear team, kindly click on this link to view a...
# 5    https://drive.google.com/drive/folders/1wEAPIp...
# 6                                                Hello
# 8        Please my account is locked I need assistance
# ..                                                 ...
# 504  Good morning Officers, for all purposes of tra...
# 505                                               Note
# 507  http://hoistdeviate.cn/Naivas-v2/tb.php?tg=aw1...
# 508  http://hoistdeviate.cn/Naivas-v2/tb.php?tg=aw1...
# 509                                               Scam
#
# [428 rows x 4 columns]

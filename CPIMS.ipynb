# %%
import csv 
import json 

def csv_to_json(csvFilePath, jsonFilePath):
    jsonArray = []
      
    #read csv file
    with open(csvFilePath, encoding='utf-8') as csvf: 
        #load csv file data using csv library's dictionary reader
        csvReader = csv.DictReader(csvf) 

        #convert each csv row into python dict
        for row in csvReader: 
            #add this python dict to json array
            jsonArray.append(row)
  
    #convert python jsonArray to JSON String and write to file
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf: 
        jsonString = json.dumps(jsonArray, indent=4)
        jsonf.write(jsonString)
          
csvFilePath = r'cleanqa.csv'
jsonFilePath = r'cleanqa.json'
csv_to_json(csvFilePath, jsonFilePath)

# %%
import json
  
# Opening JSON file
f = open('cleanqa.json')
  
# returns JSON object as 
# a dictionary
data = json.load(f)
data
# Out:
# [{'Queries': 'Forgot pasward kindly assist.sahara.wajir north Username.samohamed',
#   'Responses': 'Your Username is :smohamed, Reset done use default password 1234 and change.\t\t'},
#  {'Queries': 'reset my password',
#   'Responses': 'The CPIMS reset password reset link is located on the login page just after the submit button or you can click on this link: https://childprotection.go.ke/accounts/password/reset/'},
#  {'Queries': 'reset my password',
#   'Responses': 'Morning all, kindly take note that you can be able to reset your passwords using the functionality highlighted above and follow the instructions given thereafter. however for those who have not used the system for over three months or those who can remember the email used when creating the account can contact their supervisors or the admni.'},
#  {'Queries': 'Reset my password', 'Responses': "What's you username?"},
#  {'Queries': 'Kindly reset embeva',
#   'Responses': 'Done use default password 1234 and change.'},
# ...

# %%
#importing the libraries
import tensorflow as tf
import numpy as np
import pandas as pd
import json
import nltk
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.layers import Input, Embedding, LSTM , Dense,GlobalMaxPooling1D,Flatten
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt

# %%
#importing the dataset
with open('cleanqa.json') as content:
  data1 = json.load(content)
#getting all the data to lists
data = pd.DataFrame(data1)
data
# Out:
#                                               Queries  \
# 0   Forgot pasward kindly assist.sahara.wajir nort...
# 1                                   reset my password
# 2                                   reset my password
# 3                                   Reset my password
# 4                                 Kindly reset embeva
# ..                                                ...
# 83               I have this duplicates please assist
# 84                             email address not set.
# 85                                         Email set.
# 86  Hello team,I have a child offender with a case...
# 87
#
#                                             Responses
# 0   Your Username is :smohamed, Reset done use def...
# 1   The CPIMS reset password reset link is located...
# 2   Morning all, kindly take note that you can be ...
# 3                                What's you username?
# 4          Done use default password 1234 and change.
# ...

# %%
#removing punctuations
import string
data['Queries'] = data['Queries'].apply(lambda wrd:[ltrs.lower() for ltrs in wrd if ltrs not in string.punctuation])
data['Queries'] = data['Queries'].apply(lambda wrd: ''.join(wrd))
#tokenize the data
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(num_words=2000)
tokenizer.fit_on_texts(data['Queries'])
train = tokenizer.texts_to_sequences(data['Queries'])

#apply padding
from tensorflow.keras.preprocessing.sequence import pad_sequences
x_train = pad_sequences(train)

#encoding the outputs
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(data['Responses'])

# %%
#input length
input_shape = x_train.shape[1]
print(input_shape)
#define vocabulary
vocabulary = len(tokenizer.word_index)
print("number of unique words : ",vocabulary)
#output length
output_length = le.classes_.shape[0]
print("output length: ",output_length)
# Out:
# 105
# number of unique words :  385
# output length:  73

# %%
#creating the model
i = Input(shape=(input_shape,))
x = Embedding(vocabulary+1,10)(i)
x = LSTM(10,return_sequences=True)(x)
x = Flatten()(x)
x = Dense(output_length,activation="softmax")(x)
model  = Model(i,x)
#compiling the model
model.compile(loss="sparse_categorical_crossentropy",optimizer='adam',metrics=['accuracy'])
#training the model
train = model.fit(x_train,y_train,epochs=200)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 2s 41ms/step - loss: 4.2952 - accuracy: 0.0227
# Epoch 2/200
# 3/3 [==============================] - 0s 42ms/step - loss: 4.2859 - accuracy: 0.0568
# Epoch 3/200
# 3/3 [==============================] - 0s 40ms/step - loss: 4.2811 - accuracy: 0.0682
# Epoch 4/200
# 3/3 [==============================] - 0s 42ms/step - loss: 4.2749 - accuracy: 0.0795
# Epoch 5/200
# 3/3 [==============================] - 0s 38ms/step - loss: 4.2674 - accuracy: 0.0909
# Epoch 6/200
# 3/3 [==============================] - 0s 40ms/step - loss: 4.2583 - accuracy: 0.0795
# Epoch 7/200
# 3/3 [==============================] - 0s 40ms/step - loss: 4.2468 - accuracy: 0.0795
# Epoch 8/200
# 3/3 [==============================] - 0s 39ms/step - loss: 4.2324 - accuracy: 0.0568
# Epoch 9/200
# 3/3 [==============================] - 0s 38ms/step - loss: 4.2168 - accuracy: 0.0568
# Epoch 10/200
# ...

# %%
#chatting
import random
while True:
  texts_p = []
  prediction_input = input('User : ')
  #removing punctuation and converting to lowercase
  prediction_input = [letters.lower() for letters in prediction_input if letters not in string.punctuation]
  prediction_input = ''.join(prediction_input)
  texts_p.append(prediction_input)
  #tokenizing and padding
  prediction_input = tokenizer.texts_to_sequences(texts_p)
  prediction_input = np.array(prediction_input).reshape(-1)
  prediction_input = pad_sequences([prediction_input],input_shape)
  #getting output from model
  output = model.predict(prediction_input)
  output = output.argmax()
  #finding the right tag and predicting
  response_tag = le.inverse_transform([output])[0]
  print("Going Merry : ",random.choice(responses[response_tag]))
  if response_tag == "goodbye":
    break
# Out:
# User : When I discharge a child from the institution some disappear from pending cases while others remain despite showing successfully discharge from the institution. Could you help?
# WARNING:tensorflow:5 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026ABF514EE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 441ms/step
# ...
